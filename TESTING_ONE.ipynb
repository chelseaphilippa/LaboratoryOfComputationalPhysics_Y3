# %% [markdown]
# # Lab lectures
# 19/10/2020
# Lecture 3

# %% [markdown]
# ### Integers
# unlimited precision storage in python 3 (2 had limitations)
# N bits
# max size is 2^64 of system -- sys.maxsize but you can just add a number to it eg sys.maxsize+1
# division: / (to get nearest integer answer use // eg 2//3 returns 0, 2/3 returns 0.666)

# %% [markdown]
# ### Binary and Hexadecimal representation
# binary rep: a_bin = bin(a) -> 0b...
# hex rep: a_hex = hex(a) -> 0x...
# to get back to integer:
# int(a_bin,2) or int(a_hex,16)

# %% [markdown]
# ### Bitwise operators
# eg sensor measuring temp, humidity etc of room
# sensor returns 64 bit (or 32) words representing the measurements
# assign subset of 64bits to each property that sensor measures
# eg 1-10 t, 11-22 humidity, 23-34 pressure etc format
# to interpret info you need a programme that separates parts correctly
# need to apply a bitwise operation
# most languages have similar syntax
# --logical
# --unary
# --masks and shifts
# left shift is towards most significant, right is away from most significant
#
# ### Floating point numbers
# cannot represent w infinite precision non-integer numbers so you need a single (aka float) -32 bit or double precision number -64 bit
# people always use double now and in python use 'float' to mean 64 bit
# use three quantities to define the 64 bit characterising the number you want to store
# the final bit is the mantissa defined in notes
#
# #### Double
# bit postions for s, e and f
# validity range is 2^-308 to 2^308
# scientific calculations almost always require at least double
#
# you can print (sys.float_info) for information about representation on your system, gives min exponent, mant_dig is number of digits in the mantisse
#
# #### Accuracy with floats
# accuracy is still not infinite
# *relisten to explanation of limitations of storing numbers*
#
# ### Numbers -> functions
# well conditioned means upon application of small variation to input has a small effect
# poorly conditioned functions means a small perturbation has large effects
# very small corrections to numbers should not affect output, then algorithm is said to be numerically stable
# a product of a thousand numbers close to zero is not numerically stable, but inversion using logs is
# you will always be limited in accuracy
#
# examples of functions that have large differences and must be modified - tan(x)
# variance
#
# need to use brain to work out way to represent function that doesnt rely on limited accuracy of your system

# %% [markdown]
# ### 19/10/20 Lecture 4
# NUMPY
# ## Arrays
# grid of values of the same type and indexed by a tuple of positive integers
# defined as
# a = np.array(with two, arguments) you can specify them as integers, floats etc if you don't then the type is inferred eg np.array([1,2,4])
# can have complex numbers and they are twice as large as floats per element (complex128)
# arrays are memory-efficient containers that provide fast numerical operations
# NumPy notation: take original array and perform operation
# eg a = np.arrange(1000) -> an array with 1000 elements
# a**2
#
# nb %timeit times the operation that is performed- can compare different methods
#
# ** NumPy is more convenient and efficient **
#
# ### Dimensions
# no of dimensions is the ranke of the array
# shape of array is a tuple of integers giving size along each dimension
#
# 1D objects
# shape - length of first dimension; has one entry
# len(array) - is always first element of what array.shape will return
#
# 2D,3D etc
# simple notation
# dimensions are called axes
#
# ### Generating arrays
# * a NumPy array is not a list *
# method tolist (getting back to a list)
# eg a = np.array(1)
# a.tolist()
#
# copies and views
# define a as array
# b = a is a view
# c = a.copy() is creating a copy
# if you modify a then b is changed too, c is not
#
# np.arange(1,9,2) goes from 1 - 9 exclusive in steps of 2
# output 1,3,5,7
# or by number of points eg for plotting functions
# np.linspace(0,1,20) 20 numbers from 0 to 1 inclusive
#
# np.random is way of generating array of random numbers
# eg np.random.rand(4) makes 4 random numbers between 0 & 1
#
# ### Reshaping
# array.reshape(3,2) makes array into a 3x2 matrix
# concatenate = linking
#
# ### Indexing and slicing
# can access specific items in the array
# eg print array (a[0], a[2]) for 1D or use [x,y,z] nomenclature
# *see graphic on indexing*
# can import large datasets into your code as numpy arrays
# v efficient and good user interface
#
# fancy indexing
# can apply a mask
# eg i want all the items that satisfy a given criteria
# define array eg = np.random.randint(0,21,15)
# define mask = ()
# if item satisfies mask requirement, it returns True, else False
# apply mask to array; filtered_array = mask(array)
#
# ------
# chat about filtering array
# Isn't this just reassigning the name "filtered_a" to another (new) np.array?
# From Marcello Seppi to Everyone:  02:50 PM
# After slow mo examination I think so too
# From Rinaldi Luca to Everyone:  02:53 PM
# Just try doing
# filtered_a[0]=-1
# and then print a, the "a" array will not be modified
# From Matteo Migliorini to Everyone:  02:54 PM
# a = np.array([1,2,3,4])
# filtered = a[a%2==0]
# filtered[0] = 10
# It doesn’t modify a
# Is that what you meant?
# From Marcello Seppi to Everyone:  02:55 PM
# then why does
# a[a%2==0]  = 1
# modify a ?
# From Marco Giunta to Everyone:  02:55 PM
# because that's plain old indexing
# imho
# From Matteo Migliorini to Everyone:  02:56 PM
# Because in this way you are directly modifying a
# From Marco Giunta to Everyone:  02:56 PM
# you're accessing data inside a
# From Matteo Migliorini to Everyone:  02:56 PM
# That’s just like saying a[0] = 2
# https://scipy-cookbook.readthedocs.io/items/ViewsVsCopies.html#I-think-I-understand-what-a-view-is,-but-why-fancy-indexing-is-not-returning-a-view?
# So it is a matter of how the = operator is implemented
# name = a[a%2==0]
# creates a copy, while
# a[a%2==0] = 1
# modifies the original data
#
# ------
#
# *array multiplication is not matrix multiplication*

# %% [markdown]
# ## Lecture 4 cont. 27/10
# #### Reductions
# built in function getattr()
# sometimes in higher dimensions you have to specify the axis you want to work on
#
# #### Broadcasting
# conversion of arrays to make them the same size as each other so you can perform operations on them
#
# NumPy arrays can encapsulate large homogeneous data sets, v user friendly
#
# ### Random Numbers
# NumPy most commonly used worldwide for generation of random numbers
# theory later on in the course
# import numpy.random (as npr if you want)
# need to set a seed
# npr.seed(123)

# %%
import sys

x = int(input("press 1 for dec to bin,hex \n press 2 for bin to dec,hex \n press 3 for hex to bin,dec \n"))


if x == 1:
    decimal =int(input('Enter the decimal number: '))
    print(bin(decimal),"in binary.") 
    print(hex(decimal),"in hexadecimal.")

if x == 2:
    binary = input("Enter number in Binary Format: ");
    decimal = int(binary, 2);
    print(binary,"in Decimal =",decimal);
    print(binary,"in Hexadecimal =",hex(decimal));
    
if x == 3:
    hex = input("Enter number in hexa-decimal Format: ");
    decimal = int(hex, 16);
    print(hex,"in Decimal =",decimal);
    print(hex,"in Binary =",bin(decimal));

# %% [markdown]
# # Lecture 4 osemn
# (pronounced awesome)
# site spurious-correlations (spurious - non genuine)
# correlation is not causation
# data - property of someone, normally need permission or to pay for it
# ### Getting Data
# wget = curl on windows
#
# ### Data Formats
# datasets can be stored in diff ways
#
# Text Files -
# readibility
# low entropy
#
# CVS Files -
# import csv
#
# Binary/Hexadecimal files
# 64 bits = 8 bytes
#
# JSON files - JavaScript Object Notation, used for web content
# similar to nested Python dictionary
# cat - inline comment from bash
# or import json
# data = json.load()
#
# HDF5 files
# often used to store complex scientific data eg Matlab saves to HDF5
# import h5py
#
# #### Pandas
# most commonly used Python library
#
# ROOT - won't use in course
# store and manage complex datasets eg physics experiments where events are recorded
# to open ROOT files with non-ROOT library
# import uproot
# events = uproot.open("")["events"]
# events

# %% [markdown]
# # Lecture 5 Pandas
# most modern/advanced tool for managing large datasets efficiently
# import pandas as pd
# dont need to have homogeneous datasets - pd is extension of np functionalities
#
# more efficient way of performing operation instead of looping through rows, panda does by column 'column based'
#
# efficiency is highly desired! python is successful because it allows efficient data handling
#
# imagine excel spreadsheet - columns labelled with variables
# rows also can be labelled
# a series is a generalisation of a numpy array
# they do have an index
# label can be timestamp or other
# series: series of values with a label for every entry
# series['label'] to access element
#
# #### Time series
# quantities that have a time stamp attached
# can define a date (in order that you want)
# generates based on frequency that you decide
#
# need to specify where month and day go - order
# can access values between an interval you can specify first and last label boundaries
#
# ### DataFrame - main subject of lecture
# think of pandas as modern interpretation of excel tables
# table with labels for rows and columns
# panda offers more functionalities
# made of series of homogenous records - same set of variables
# developed for 'R' - most used language for stats analysis
#
# can have missing items/features in a record
# every record needs to have same formatting
#
# keys of dictionary rep features - column labels
# what comes after is the element of the column
#
# typically have millions of records
#
# axis=0 row labels
# axis=1 column labels
# df = dataframe
# df.sort_values(by="name of column label")
# will sort from lowest value in that column
#
# selection by label
# df.loc[]
# loc - doesnt use () it uses []
# [rows selection, columns selection]
# also
# df.at() for selecting one row and one column
# also
# df.iloc[numbers not labels]
#
# loc - returns a copy
# eg a = df.loc[]
# if you change a, doesnt change content of df
#
# iloc - returns a view
# if you create a view then changes would affect df
#
# **need to be careful**
#
# ### boolean index
#
# edit d column
# df.loc[:, 'D'] = np.array[5]*len(df) (5s for whole length)
#
# cosine of entire column - quicker than looping over rows
#
# df2 = df.copy() to generate copy
#
# df = df.drop(columns = "label") to remove column and generate copy
#
# df_wNan (with not a number)
#
# filling missing data
# df_wNan.fillna(value=0) to sub in with a given value eg 0
#
# ### operations
# mean of columns axis = 1 (or rows axis = 0)
#
# -- lecture continued 10.11.2020 --
#
# Pandas = how to deal with data
# how to embed data into structure that facilitates processing and management of data
#
# nb columns - features/variables
# rows - records/entries
#
# faster to perform computation on column not looping through data **NO COMPARISON**
#
# #### grouping
#
# split into groups based on certain criteria
# then apply fn to specific group independantly
# can combine results
#
# might want to perform sophisticated op on only one subset
# 'group by' functionality
# df.groupby()
#
# series - a column of a df
#
# ##### multiindexing
# can occur both on rows and on features(columns)
# can group for multiple columns if one column has multiple indexes in the next column
#
# #### Plotting
# next lab class
# very convenient
# relies on matplotlib library

# %% [markdown]
# # LECTURE 6
# ## visualisation

# %% [markdown]
# ### General stuff
#
# example higgs boson plot - GOOD
# blue; background
# faster than light particle graphics - BAD
#
# #### Histograms
# represent scalar plots - bad for d > 2
# used to display distribution of features
# use them bc you want to compare different distributions to see similarities
# if you have a model/theory you can produce simulated data and then check compared to real data to make sure they are alike
# they are 'binned', split data into 'bins'. Typically bin sizes are all the same, but not mandatory.
# pointless to draw gaussian in centre and leave the majority of your plot empty.
#
# Information conveyed by histogram:
#     number of counts;normalisation (measurements or simulated data points)
#     shape of distribution
#
# can be seperated. Can normalise each data point individually so that overall normalisation is one.
#
# #### Scatter Plots
# you have a record (two variables) and plot with one on x and one on y.
# useful for visual analysis and can convey information. get possible correlation between the two variables.
# place point with precision in xy plane, therefore unbinned. If you fill up xy plane, may bin data in order to distinguish correlation or density. Use different colours for different densities.
#
# #### Contour Plots
# same as for scatter plots.
# map density of data in that region against altitude. Also regularly combines with colours.
#
#
# library in python for plotting: several available
# ### Matplotlib (pyplot)
# a hierachy of nested python objects
# the first one that you come to is called a figure - a container for all graphics matplotlib can provide.
# **an axes is a plot**
# plt.show()
#
# ### Seaborn
# a library 'wrapper' ar

# %% [markdown]
# # Lecture 7 Algorithms
# scipy library
# all methods are from numpy and some complex algorithms from scipy
#
# ### time complexity
# want to assess performances of algorithm wrt size of input
# define algorithm to be order g(n) in case where fn is bound/constant
# even though 2 algorithms might have same complexity (eg scale with n) they might feature diff scaling in absolute terms eg 0.1n or 10n. care about scaling wrt size but complexity defined wrt given function on order of that function, not on its exact size
#
# ### size complexity
# or other competing resources eg memory - need data to sit in memory
# want to not be using too much wrt to how much is actually needed - be #smort
# eg use view instead of copy
#
# ## linear algebra
# scipy.linalg has la commands
# nb remember what covariance of a matrix is
# take mean of each of the objects(rows) then invert it
# mean of each of the vectors is 0
# covariant matrix calculation example in doc
#
# ### Matrix decomposition
# def a = lu
# l = lower part
# u = upper part
#
# two steps: ax = b = lux
# ly = b
# ux = y
# ### eigendecomposition
# -- square matrix
# a = LAL^-1 L - eigenvectors
# detA-lamba(1) = 0 - lamba = eigenvalues
#
# singular value decomposition
# -- not square matrix
# A = UDV^T
# A - mxn matrix
# U - mxm
# D diagonal mxn
# V - nxn
#
# ### Principal component analysis
# covariance - tells you which variables have largest variance
# higher dimensional data normally has variance in a couple of variables - can discard other ones that arent useful
# imagine 10 columns (features) in pandas df
# want to extract as much info as poss about behaviour of data
# add column with zeros
# if you pass df to someone else, they will immediately drop column w zeros
# if you had put something almost zero eg 0.0033 0.0004
# they will still drop that column bc variation is negligible
# most events display basically the same variable
#
# if in a given dataset a given variable is not variant then discard it bc it doesnt show you anything
# we want the variables w the largest variance
# need to find these variables in the dataset
# need to find right rotation of system to find orthonormal quantities and between them check which vary the most and drop the others
#
# take matrix and do eigendecomposition of covariant matrix == same as taking df/numpy array and do a singular value decomposition (SVD) on it
#
# eg system w two variable w a thousand measurements
# they are correlated - cov mat not diagonal
#
# the larger the eigenvalue the larger the variation that it represents
# length of eigenvectors prop to eigenvalues
#
# now we have matrix v (rotation required of data to get eigenvectors as basis)
