# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
import random
randomlist = [random.randint(1,20) for i in range(25)]
print(randomlist)
mylist = str(randomlist)

MyFile = open("simple_data.txt", 'w')
MyFile.writelines(mylist)
MyFile.close()
# Out:
# [4, 13, 15, 10, 16, 9, 4, 11, 11, 8, 8, 3, 11, 16, 16, 12, 17, 20, 13, 13, 9, 20, 14, 2, 11]

# %%
MyFile = open("simple_data.txt", "r")
content = MyFile.read()
print(content)
MyFile.close()
# Out:
# [4, 13, 15, 10, 16, 9, 4, 11, 11, 8, 8, 3, 11, 16, 16, 12, 17, 20, 13, 13, 9, 20, 14, 2, 11]

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
import numpy.random as npr
npr.seed(2345)
array = npr.rand(5,5)
print(array, "\n")

file = open("data.txt", 'w+')

content = str(array)
file.write(content)
file.close()

#to display contents
file = open("data.txt", "r")
content = file.read()

print(content)
file.close()
# Out:
# [[0.66064431 0.41360065 0.66810256 0.22994342 0.80767834]
#  [0.63681846 0.17219385 0.26038587 0.91531999 0.46281551]
#  [0.12019095 0.88088551 0.22621895 0.81144033 0.44587892]
#  [0.09945494 0.89445394 0.63963019 0.93079198 0.8535982 ]
#  [0.84183989 0.55101815 0.2090729  0.87289664 0.87130821]]
#
# [[0.66064431 0.41360065 0.66810256 0.22994342 0.80767834]
#  [0.63681846 0.17219385 0.26038587 0.91531999 0.46281551]
#  [0.12019095 0.88088551 0.22621895 0.81144033 0.44587892]
#  [0.09945494 0.89445394 0.63963019 0.93079198 0.8535982 ]
#  [0.84183989 0.55101815 0.2090729  0.87289664 0.87130821]]

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
#import csv
import re
MyFile = open("data.txt", 'r')
content = MyFile.read()
b = ""
for value in content:
    b += value
    b += ","
#print(content)
#print(b)
#np.savetxt("my_file1.csv", MyFile, delimiter=',')
#print(MyFile)
MyFile.close()

#comma separated values = csv
import csv
myfile = open("data.txt", "r")
content = myfile.read()
print(content)

with open('data.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=' ', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in content:
        writer.writerow(row)
myfile.close()
# Out:
# [[0.66064431 0.41360065 0.66810256 0.22994342 0.80767834]
#  [0.63681846 0.17219385 0.26038587 0.91531999 0.46281551]
#  [0.12019095 0.88088551 0.22621895 0.81144033 0.44587892]
#  [0.09945494 0.89445394 0.63963019 0.93079198 0.8535982 ]
#  [0.84183989 0.55101815 0.2090729  0.87289664 0.87130821]]

# %%
import csv 
  
# opening the CSV file 
with open('data.csv', mode ='r')as file: 
    
  # reading the CSV file 
    csvFile = csv.reader(file) 
  
  # displaying the contents of the CSV file 
    for lines in csvFile: 
        print(lines)
# Out:
# ['[']
# ['[']
# ['0']
# ['.']
# ['6']
# ['6']
# ['0']
# ['6']
# ['4']
# ['4']
# ['3']
# ['1']
# ['| |']
# ['0']
# ['.']
# ['4']
# ['1']
# ['3']
# ['6']
# ['0']
# ['0']
# ['6']
# ['5']
# ['| |']
# ['0']
# ['.']
# ['6']
# ['6']
# ['8']
# ['1']
# ['0']
# ['2']
# ['5']
# ['6']
# ['| |']
# ['0']
# ['.']
# ['2']
# ['2']
# ['9']
# ['9']
# ['4']
# ['3']
# ['4']
# ['2']
# ['| |']
# ['0']
# ['.']
# ['8']
# ['0']
# ['7']
# ['6']
# ['7']
# ['8']
# ['3']
# ['4']
# [']']
# ['|']
# ['|']
# ['| |']
# ['[']
# ['0']
# ['.']
# ['6']
# ['3']
# ['6']
# ['8']
# ['1']
# ['8']
# ['4']
# ['6']
# ['| |']
# ['0']
# ['.']
# ['1']
# ['7']
# ['2']
# ['1']
# ['9']
# ['3']
# ['8']
# ['5']
# ['| |']
# ['0']
# ['.']
# ['2']
# ['6']
# ['0']
# ['3']
# ['8']
# ['5']
# ['8']
# ['7']
# ['| |']
# ['0']
# ['.']
# ['9']
# ['1']
# ['5']
# ['3']
# ['1']
# ['9']
# ['9']
# ['9']
# ['| |']
# ['0']
# ['.']
# ['4']
# ['6']
# ['2']
# ['8']
# ['1']
# ['5']
# ['5']
# ['1']
# [']']
# ['|']
# ['|']
# ['| |']
# ['[']
# ['0']
# ['.']
# ...

# %%
type(MyFile)
# Out:
# _io.TextIOWrapper

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
file_name = "credit_card.dat"
infile = open(file_name, 'r')
data = [line for line in infile]
print(data)
#print(infile)
print(list(infile))
data1 = infile.read()
print(data1)
myarray = np.fromfile('credit_card.dat', dtype = "float")
print(myarray)
infile.close()
# Out:
# ['1101111101101101001110001000001101011101101101111100111000001100111101111101111101011000001100101100101101111100011010\n', '1100111100101101011101111000001110001100101101001101111000001100111100111101011101001000001100101100101101101101101010\n', '1100101101111100101100101000001100001100001100001100011000001101001100001100011100011000001101101101101101011100101010\n', '1100001101101101101100011000001100111100001101101100111000001100111101111101001100101000001100111100011101011100001010\n', '1100001101001100111100101000001100011101101100001110001000001100011101001101101100101000001101001101111101001100101010\n', '1101011110001100101101111000001100101100001100101101111000001110001101111110001101011000001101111100111100001100111010\n', '1101011101111101111101001000001110001101011100101110001000001100101100001110001101111000001100011100011100011101111010\n', '1110001100011101001100001000001100011100101100011100001000001101101100111101011100101000001100101110001101001101011010\n', '1101
# ...

# %%
numlist= [122, 324, 111, 789, 111]
character = [chr(n) for n in numlist]
print(character)

list(map(chr, numlist))
# Out:
# ['z', 'ń', 'o', '̕', 'o']
# ['z', 'ń', 'o', '̕', 'o']

# %%
with open(file_name, mode='r') as file:
    fileContent = file.read().split()
    for line in fileContent:
        print(line)
        print(len(line))
        num = 0
        char = 0
        while num < (len(line)-4):
            print("num init", num)
            a = line[num:(num+6)]
            print(a)
            print(int(a,2))
            num = num + 6
            print("num end", num)
            print("char", char)
            char += 1
        print("end credit card number")
#print(fileContent)
import struct
ints = struct.unpack('i', fileContent[1])
print(ints)
# Out:
# 1101111101101101001110001000001101011101101101111100111000001100111101111101111101011000001100101100101101111100011010
# 118
# num init 0
# 110111
# 55
# num end 6
# char 0
# num init 6
# 110110
# 54
# num end 12
# char 1
# num init 12
# 110100
# 52
# num end 18
# char 2
# num init 18
# 111000
# 56
# num end 24
# char 3
# num init 24
# 100000
# 32
# num end 30
# char 4
# num init 30
# 110101
# 53
# num end 36
# char 5
# num init 36
# 110110
# 54
# num end 42
# char 6
# num init 42
# 110111
# 55
# num end 48
# char 7
# num init 48
# 110011
# 51
# num end 54
# char 8
# num init 54
# 100000
# 32
# num end 60
# char 9
# num init 60
# 110011
# 51
# num end 66
# char 10
# num init 66
# 110111
# 55
# num end 72
# char 11
# num init 72
# 110111
# 55
# num end 78
# char 12
# num init 78
# 110101
# 53
# num end 84
# char 13
# num init 84
# 100000
# 32
# num end 90
# char 14
# num init 90
# 110010
# 50
# num end 96
# char 15
# num init 96
# 110010
# 50
# num end 102
# char 16
# num init 102
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json
import csv

data = json.load(open('user_data.json'))

filtered_data = [line for line in data if line["CreditCardType"] == "American Express"]
#print(filtered_data)
file.close()

file = open('americanexpress.csv', 'w+')
file.write(str(filtered_data))
file.close()

# %%
# opening the CSV file     
with open('americanexpress.csv', mode ='r') as file: 

  # reading the CSV file 
    csvFile = csv.reader(file) 
  
  # displaying the contents of the CSV file 
    for lines in csvFile: 
        print(lines)
# Out:
# ["[{'ID': '2'", " 'JobTitle': 'Investment  Advisor'", " 'EmailAddress': 'Clint_Thorpe5003@bulaffy.com'", " 'FirstNameLastName': 'Clint Thorpe'", " 'CreditCard': '7083-8766-0251-2345'", " 'CreditCardType': 'American Express'}", " {'ID': '12'", " 'JobTitle': 'Retail Trainee'", " 'EmailAddress': 'Phillip_Carpenter9505@famism.biz'", " 'FirstNameLastName': 'Phillip Carpenter'", " 'CreditCard': '3657-0088-0820-5247'", " 'CreditCardType': 'American Express'}", " {'ID': '28'", " 'JobTitle': 'Project Manager'", " 'EmailAddress': 'Russel_Graves1378@extex.org'", " 'FirstNameLastName': 'Russel Graves'", " 'CreditCard': '6718-4818-8011-6024'", " 'CreditCardType': 'American Express'}", " {'ID': '39'", " 'JobTitle': 'Stockbroker'", " 'EmailAddress': 'Leanne_Newton1268@typill.biz'", " 'FirstNameLastName': 'Leanne Newton'", " 'CreditCard': '5438-0816-4166-4847'", " 'CreditCardType': 'American Express'}", " {'ID': '57'", " 'JobTitle': 'Budget Analyst'", " 'EmailAddress': 'Tony_Giles1960@iatim.tech'", 
# ...

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe what you see

# %%
import pandas as pd
dataset = pd.read_csv('https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1')
dataset.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
dataset.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
dataset.hist('class')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002564753E6D0>]],
#       dtype=object)

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
df7 = pd.read_csv('https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1')
df7.head()
# Out:
#         label  features_1  features_2  features_3  features_4  features_5  \
# 0  -89.243497    2.175170   -0.285786   -0.603396   -0.627453   -0.686474
# 1  230.050125    1.481941   -1.327870   -0.543583   -0.303578    1.552964
# 2 -286.844411   -1.154394   -0.178649   -1.636646    0.239353   -0.684994
# 3  364.552862    0.197665    1.455707    1.562205    2.168207    0.053335
# 4  515.460006    0.596676    0.969860    1.294158   -0.404728    2.145297
#
#    features_6  features_7  features_8  features_9  ...  features_11  \
# 0    0.381067    0.306205   -0.637447   -1.332087  ...     1.290725
# 1    0.549738   -0.763094   -0.455796    2.053388  ...    -1.761306
# 2    0.587201   -0.209564   -0.428956   -0.757998  ...     0.374645
# 3    0.790492   -0.212023   -1.142483   -1.124906  ...     0.712160
# 4    0.997481   -0.541670   -0.952850   -0.592084  ...    -1.347072
#
#    features_12  features_13  features_14  features_15  features_16  \
# ...

# %%
df7.plot.scatter('features_1', 'features_2', c="DarkBlue")
df7.plot.scatter('features_1', 'features_3')
df7.plot.scatter('features_3', 'features_2', c = "Pink")

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
dataset8 = pd.read_csv('https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1')
dataset8.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
result = dataset8.to_json(orient = "records")
json.loads(result)
# Out:
# [{'class': 1,
#   'cap-shape': 5,
#   'cap-surface': 2,
#   'cap-color': 4,
#   'bruises': 1,
#   'odor': 6,
#   'gill-attachment': 1,
#   'gill-spacing': 0,
#   'gill-size': 1,
#   'gill-color': 4,
#   'stalk-shape': 0,
#   'stalk-root': 3,
#   'stalk-surface-above-ring': 2,
#   'stalk-surface-below-ring': 2,
#   'stalk-color-above-ring': 7,
#   'stalk-color-below-ring': 7,
#   'veil-type': 0,
#   'veil-color': 2,
#   'ring-number': 1,
#   'ring-type': 4,
#   'spore-print-color': 2,
#   'population': 3,
#   'habitat': 5},
#  {'class': 0,
#   'cap-shape': 5,
#   'cap-surface': 2,
#   'cap-color': 9,
#   'bruises': 1,
#   'odor': 0,
#   'gill-attachment': 1,
#   'gill-spacing': 0,
#   'gill-size': 0,
#   'gill-color': 4,
#   'stalk-shape': 0,
#   'stalk-root': 2,
#   'stalk-surface-above-ring': 2,
#   'stalk-surface-below-ring': 2,
#   'stalk-color-above-ring': 7,
#   'stalk-color-below-ring': 7,
#   'veil-type': 0,
#   'veil-color': 2,
#   'ring-number': 1,
#   'ring-type': 4,
# ...
